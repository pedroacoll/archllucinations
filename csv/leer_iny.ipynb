# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
directory_merc='/Users/pedroguillermarnanzcoll/Documents/AI/repo/dataset/1260/1260_mercator'

# %%
array = np.load("/Users/pedroguillermarnanzcoll/Documents/AI/Arquitectura/csv/1260_mercator/17_b.npy")

# %%
array.shape
# Out:
# (1071, 21, 60)

# %%
a=array[4262%1071,4,45]
a
# Out:
# -0.889003869980432

# %%
plt.imshow(array[4262%1071, :, :],cmap='Greys',interpolation='spline16')
#plt.savefig('explicacion.png')

# %%
for i in range(array.shape[0]):
    plt.axis('off')
    plt.imshow(array[i, :, :],cmap='Greys',interpolation='spline16')
    plt.savefig(directory_merc+'/25c'+'_'+str(format(i,'05d'))+'.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-580a3eaca211> in <module>
#       2     plt.axis('off')
#       3     plt.imshow(array[i, :, :],cmap='Greys',interpolation='spline16')
# ----> 4     plt.savefig(directory_merc+'/25c'+'_'+str(format(i,'05d'))+'.png')
#       5
#
# ~/anaconda3/envs/DL/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721     fig = gcf()
#     722     res = fig.savefig(*args, **kwargs)
# --> 723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#     725
#
# ~/anaconda3/envs/DL/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
# ...
